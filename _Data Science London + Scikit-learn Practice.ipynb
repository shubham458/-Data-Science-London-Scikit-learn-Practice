# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train = pd.read_csv(r'C:\Users\user\Desktop\kaggle data new\train.csv' , header=None)
train.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.299403 -1.226624  1.498425 -1.176150  5.289853  0.208297  2.404498
# 1 -1.174176  0.332157  0.949919 -1.285328  2.199061 -0.151268 -0.427039
# 2  1.192222 -0.414371  0.067054 -2.233568  3.658881  0.089007  0.203439
# 3  1.573270 -0.580318 -0.866332 -0.603812  3.125716  0.870321 -0.161992
# 4 -0.613071 -0.644204  1.112558 -0.032397  3.490142 -0.011935  1.443521
#
#          7         8         9   ...        30        31        32        33  \
# 0  1.594506 -0.051608  0.663234  ... -0.850465 -0.622990 -1.833057  0.293024
# 1  2.619246 -0.765884 -0.093780  ... -0.819750  0.012037  2.038836  0.468579
# 2 -4.219054 -1.184919 -1.240310  ... -0.604501  0.750054 -3.360521  0.856988
# 3  4.499666  1.038741 -1.092716  ...  1.022959  1.275598 -3.480110 -1.065252
# 4 -4.290282 -1.761308  0.807652  ...  0.513906 -1.803473  0.518579 -0.205029
#
#          34        35        36        37        38        39
# ...

# %%
test = pd.read_csv(r'C:\Users\user\Desktop\kaggle data new\test.csv',header =None)
test.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0  2.808909 -0.242894 -0.546421  0.255162  1.749736 -0.030458 -1.322071
# 1 -0.374101  0.537669  0.081063  0.756773  0.915231  2.557282  3.703187
# 2 -0.088370  0.154743  0.380716 -1.176126  1.699867 -0.258627 -1.384999
# 3 -0.685635  0.501283  1.873375  0.215224 -3.983468 -0.103637  4.136113
# 4  0.350867  0.721897 -0.477104 -1.748776 -2.627405  1.075433  4.954253
#
#          7         8         9   ...        30        31        32        33  \
# 0  3.578071 -0.667578 -0.884257  ... -0.261688 -0.224375 -1.675606 -0.479584
# 1  1.673835 -0.764122 -1.228040  ... -0.969463  0.574154 -2.200519 -1.612240
# 2  1.093584  1.596633  0.230631  ... -0.769885 -0.005143  1.467490  0.483803
# 3 -0.225431 -1.515015 -1.071763  ...  0.968609  2.386412 -0.131219  0.285646
# 4 -3.293501 -0.760369  0.204360  ...  0.260553 -2.045650 -2.173227  0.372992
#
#          34        35        36        37        38        39
# ...

# %%
trainLabels = pd.read_csv(r'C:\Users\user\Desktop\kaggle data new\trainLabels.csv',header=None)

# %%
trainLabels.head()
# Out:
#    0
# 0  1
# 1  0
# 2  0
# 3  1
# 4  0

# %%
train.count()
# Out:
# 0     1000
# 1     1000
# 2     1000
# 3     1000
# 4     1000
# 5     1000
# 6     1000
# 7     1000
# 8     1000
# 9     1000
# 10    1000
# 11    1000
# 12    1000
# 13    1000
# 14    1000
# 15    1000
# 16    1000
# 17    1000
# 18    1000
# 19    1000
# 20    1000
# 21    1000
# 22    1000
# 23    1000
# 24    1000
# 25    1000
# 26    1000
# 27    1000
# 28    1000
# 29    1000
# 30    1000
# 31    1000
# 32    1000
# 33    1000
# 34    1000
# 35    1000
# 36    1000
# 37    1000
# 38    1000
# 39    1000
# dtype: int64

# %%
train.describe()
# Out:
#                 0            1            2            3            4   \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean      0.025596    -0.024526    -0.024088    -0.002271     1.092329
# std       1.008282     1.016298     0.979109     0.970575     4.538834
# min      -3.365711    -3.492086    -2.695602    -3.460471   -16.421901
# 25%      -0.669010    -0.693937    -0.698830    -0.617557    -1.801997
# 50%       0.027895    -0.033194     0.008145     0.002327     0.862818
# 75%       0.762520     0.682753     0.661434     0.640743     3.843172
# max       3.326246     3.583870     2.546507     3.088738    17.565345
#
#                 5            6            7            8            9   ...  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000  ...
# mean     -0.006250     0.497342    -0.037883     0.026391    -0.003597  ...
# std       0.989128     2.118819     2.232256     1.001064     1.013520  ...
# ...

# %%
trainLabels.isnull().sum()
# Out:
# 0    0
# dtype: int64

# %%
trainLabels .columns =['label']
m_train =pd.merge(train,trainLabels,left_index =True,right_index =True)
m_train.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.299403 -1.226624  1.498425 -1.176150  5.289853  0.208297  2.404498
# 1 -1.174176  0.332157  0.949919 -1.285328  2.199061 -0.151268 -0.427039
# 2  1.192222 -0.414371  0.067054 -2.233568  3.658881  0.089007  0.203439
# 3  1.573270 -0.580318 -0.866332 -0.603812  3.125716  0.870321 -0.161992
# 4 -0.613071 -0.644204  1.112558 -0.032397  3.490142 -0.011935  1.443521
#
#           7         8         9  ...        31        32        33        34  \
# 0  1.594506 -0.051608  0.663234  ... -0.622990 -1.833057  0.293024  3.552681
# 1  2.619246 -0.765884 -0.093780  ...  0.012037  2.038836  0.468579 -0.517657
# 2 -4.219054 -1.184919 -1.240310  ...  0.750054 -3.360521  0.856988 -2.751451
# 3  4.499666  1.038741 -1.092716  ...  1.275598 -3.480110 -1.065252  2.153133
# 4 -4.290282 -1.761308  0.807652  ... -1.803473  0.518579 -0.205029 -4.744566
#
#          35        36        37        38        39  label
# ...

# %% [raw]
# plt.figure(figsize=(25,25))
# sns.heatmap(m_train.corr(), annot=True)

# %%
train.hist(figsize =(20,20))
# Out:
# array([[<AxesSubplot:title={'center':'0'}>,
#         <AxesSubplot:title={'center':'1'}>,
#         <AxesSubplot:title={'center':'2'}>,
#         <AxesSubplot:title={'center':'3'}>,
#         <AxesSubplot:title={'center':'4'}>,
#         <AxesSubplot:title={'center':'5'}>],
#        [<AxesSubplot:title={'center':'6'}>,
#         <AxesSubplot:title={'center':'7'}>,
#         <AxesSubplot:title={'center':'8'}>,
#         <AxesSubplot:title={'center':'9'}>,
#         <AxesSubplot:title={'center':'10'}>,
#         <AxesSubplot:title={'center':'11'}>],
#        [<AxesSubplot:title={'center':'12'}>,
#         <AxesSubplot:title={'center':'13'}>,
#         <AxesSubplot:title={'center':'14'}>,
#         <AxesSubplot:title={'center':'15'}>,
#         <AxesSubplot:title={'center':'16'}>,
#         <AxesSubplot:title={'center':'17'}>],
#        [<AxesSubplot:title={'center':'18'}>,
#         <AxesSubplot:title={'center':'19'}>,
#         <AxesSubplot:title={'center':'20'}>,
# ...

# %%
m_train
# Out:
#             0         1         2         3          4         5         6  \
# 0    0.299403 -1.226624  1.498425 -1.176150   5.289853  0.208297  2.404498
# 1   -1.174176  0.332157  0.949919 -1.285328   2.199061 -0.151268 -0.427039
# 2    1.192222 -0.414371  0.067054 -2.233568   3.658881  0.089007  0.203439
# 3    1.573270 -0.580318 -0.866332 -0.603812   3.125716  0.870321 -0.161992
# 4   -0.613071 -0.644204  1.112558 -0.032397   3.490142 -0.011935  1.443521
# ..        ...       ...       ...       ...        ...       ...       ...
# 995 -0.310429  0.826811 -0.952245  0.768850   1.877520  1.320646  1.944609
# 996 -1.853879  0.246726  0.459921 -2.074267   7.599220 -0.138355 -4.501900
# 997  0.912748 -1.734039 -1.047035  0.217573  13.457812  0.162771 -2.250521
# 998  2.439780 -0.735511 -0.902426  1.365036 -10.430299 -0.856859  2.686474
# 999  0.228994 -0.085453  0.876582  1.057401  -1.404015 -1.091965  0.639176
#
# ...

# %%
int_cols = train.columns
fig, ax= plt.subplots(nrows=10, ncols=4, figsize=(40,20), constrained_layout=True)
plt.suptitle('Feature distribution by label', size=20, weight='bold')
ax=ax.flatten()
for x, i in enumerate(int_cols):
    sns.boxplot(data=m_train, y=i, x='label', ax=ax[x])
    for s in ['left','right','top','bottom']:
        ax[x].spines[s].set_visible(False)

# %%
values_freq = m_train["label"].value_counts()
print(values_freq)
values_freq.plot(kind='pie', autopct='%1.1f%%')
plt.title('values_freq')
plt.axis('equal')
plt.show()
# Out:
# 1    510
# 0    490
# Name: label, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
x_train = scaler.fit_transform(train.values)

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x_train, trainLabels.values, test_size=0.1, shuffle=True)

# %%
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((900, 40), (100, 40), (900, 1), (100, 1))

# %%
from sklearn.metrics import accuracy_score, precision_recall_fscore_support, confusion_matrix

def print_score(y_pred, y_real):
    print("Accuracy: ", accuracy_score(y_real, y_pred))

    print()
    print("Macro precision_recall_fscore_support (macro) average")
    print(precision_recall_fscore_support(y_real, y_pred, average="macro"))

    print()
    print("Macro precision_recall_fscore_support (micro) average")
    print(precision_recall_fscore_support(y_real, y_pred, average="micro"))

    print()
    print("Macro precision_recall_fscore_support (weighted) average")
    print(precision_recall_fscore_support(y_real, y_pred, average="weighted"))
    
    print()
    print("Confusion Matrix")
    print(confusion_matrix(y_real, y_pred))

# %%
from sklearn.model_selection import GridSearchCV

def get_trained_grid(model, grid_params, x_train, y_train ,refit=True, cv=10, verbose=1):
    grid = GridSearchCV(model, grid_params, refit=refit, cv=cv, verbose=verbose)
    grid.fit(x_train, y_train)
    return grid

# %%
def get_grid_best_params(grid):
    print(grid.best_params_)
    print(grid.best_estimator_)

# %%
def print_grid_performance(grid, x_test, y_test):
    y_pred = grid.predict(x_test)
    print_score(y_pred, y_test)

# %%
from sklearn.linear_model import SGDClassifier

# %time
grid_params = { "loss": ["hinge", "log", "modified_huber"],
               "penalty": ["l1", "l2", "elasticnet"]   
}

grid = get_trained_grid(SGDClassifier(), grid_params, x_train, y_train)
get_grid_best_params(grid)
# Out:
# Wall time: 0 ns
# Fitting 10 folds for each of 9 candidates, totalling 90 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# C:\Users\user\anaconda3\anac\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\user\anaconda3\anac\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\user\anaconda3\anac\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# ...

# %%
print_grid_performance(grid, x_test, y_test)
# Out:
# Accuracy:  0.81
#
# Macro precision_recall_fscore_support (macro) average
# (0.8275401069518716, 0.7969696969696969, 0.801234438748823, None)
#
# Macro precision_recall_fscore_support (micro) average
# (0.81, 0.81, 0.81, None)
#
# Macro precision_recall_fscore_support (weighted) average
# (0.8220588235294117, 0.81, 0.8054085155350978, None)
#
# Confusion Matrix
# [[30 15]
#  [ 4 51]]

# %%
from sklearn.neighbors import KNeighborsClassifier

# %time
grid_params = { "n_neighbors": np.arange(1,50)}

grid = get_trained_grid(KNeighborsClassifier(), grid_params, x_train, y_train)
get_grid_best_params(grid)
# Out:
# Wall time: 0 ns
# Fitting 10 folds for each of 49 candidates, totalling 490 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# C:\Users\user\anaconda3\anac\lib\site-packages\sklearn\model_selection\_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\user\anaconda3\anac\lib\site-packages\sklearn\model_selection\_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# ...

# %%
print_grid_performance(grid, x_test, y_test)
# Out:
# Accuracy:  0.89
#
# Macro precision_recall_fscore_support (macro) average
# (0.8884863123993558, 0.8898989898989899, 0.8891017239641092, None)
#
# Macro precision_recall_fscore_support (micro) average
# (0.89, 0.89, 0.89, None)
#
# Macro precision_recall_fscore_support (weighted) average
# (0.890378421900161, 0.89, 0.8900998084484323, None)
#
# Confusion Matrix
# [[40  5]
#  [ 6 49]]

# %%
from sklearn.naive_bayes import GaussianNB

# %time
grid_params = { "var_smoothing": [1e-09] }

grid = get_trained_grid(GaussianNB(), grid_params, x_train, y_train)
get_grid_best_params(grid)
# Out:
# Wall time: 0 ns
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# {'var_smoothing': 1e-09}
# GaussianNB()
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# C:\Users\user\anaconda3\anac\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\user\anaconda3\anac\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\user\anaconda3\anac\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# ...

# %%
print_grid_performance(grid, x_test, y_test)
# Out:
# Accuracy:  0.82
#
# Macro precision_recall_fscore_support (macro) average
# (0.8191276510604242, 0.8222222222222222, 0.8193496587715776, None)
#
# Macro precision_recall_fscore_support (micro) average
# (0.82, 0.82, 0.82, None)
#
# Macro precision_recall_fscore_support (weighted) average
# (0.8234893957583034, 0.82, 0.8204335608189481, None)
#
# Confusion Matrix
# [[38  7]
#  [11 44]]

# %%
from sklearn.tree import DecisionTreeClassifier

# %time
grid_params = {'criterion': ["gini", "entropy"], 
              'splitter': ['best', 'random'], 
              'max_depth': [3,4,None], 
              'min_samples_split':[2, 4, 6],
              'min_samples_leaf':[1,2,3]}

grid = get_trained_grid(DecisionTreeClassifier(), grid_params, x_train, y_train)
get_grid_best_params(grid)
# Out:
# Wall time: 0 ns
# Fitting 10 folds for each of 108 candidates, totalling 1080 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}
# DecisionTreeClassifier(criterion='entropy')
# [Parallel(n_jobs=1)]: Done 1080 out of 1080 | elapsed:   13.8s finished

# %%
print_grid_performance(grid, x_test, y_test)
# Out:
# Accuracy:  0.81
#
# Macro precision_recall_fscore_support (macro) average
# (0.81, 0.8131313131313131, 0.8095238095238095, None)
#
# Macro precision_recall_fscore_support (micro) average
# (0.81, 0.81, 0.81, None)
#
# Macro precision_recall_fscore_support (weighted) average
# (0.815, 0.81, 0.8104761904761904, None)
#
# Confusion Matrix
# [[38  7]
#  [12 43]]

# %%
from sklearn.ensemble import RandomForestClassifier

# %time
grid_params = {'n_estimators': [10, 20, 50], 
              'max_features': ['auto', 'sqrt', 'log2'], 
              'bootstrap': [True, False], 
              'criterion':['entropy', 'gini']}

grid = get_trained_grid(RandomForestClassifier(), grid_params, x_train, y_train)
get_grid_best_params(grid)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# C:\Users\user\anaconda3\anac\lib\site-packages\sklearn\model_selection\_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# Wall time: 0 ns
# Fitting 10 folds for each of 36 candidates, totalling 360 fits
# C:\Users\user\anaconda3\anac\lib\site-packages\sklearn\model_selection\_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# ...

# %%
print_grid_performance(grid, x_test, y_test)
# Out:
# Accuracy:  0.85
#
# Macro precision_recall_fscore_support (macro) average
# (0.8500000000000001, 0.8535353535353536, 0.849624060150376, None)
#
# Macro precision_recall_fscore_support (micro) average
# (0.85, 0.85, 0.85, None)
#
# Macro precision_recall_fscore_support (weighted) average
# (0.855, 0.85, 0.8503759398496241, None)
#
# Confusion Matrix
# [[40  5]
#  [10 45]]

# %%
from sklearn import svm

# %time
grid_params = { "kernel": ["linear", "poly", "rbf", "sigmoid"],
               "degree": [1, 2 ,3, 4, 5, 6] }

grid = get_trained_grid(svm.SVC(), grid_params, x_train, y_train)
get_grid_best_params(grid)
# Out:
# Wall time: 0 ns
# Fitting 10 folds for each of 24 candidates, totalling 240 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# C:\Users\user\anaconda3\anac\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\user\anaconda3\anac\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\user\anaconda3\anac\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# ...

# %%
print_grid_performance(grid, x_test, y_test)
# Out:
# Accuracy:  0.87
#
# Macro precision_recall_fscore_support (macro) average
# (0.8693181818181819, 0.8676767676767676, 0.868407733576273, None)
#
# Macro precision_recall_fscore_support (micro) average
# (0.87, 0.87, 0.87, None)
#
# Macro precision_recall_fscore_support (weighted) average
# (0.8698863636363637, 0.87, 0.869855248506934, None)
#
# Confusion Matrix
# [[38  7]
#  [ 6 49]]

# %%
from sklearn.naive_bayes import BernoulliNB

# %time
grid_params = {'alpha': [0.25, 0.5, 1]}

grid = get_trained_grid(BernoulliNB(), grid_params, x_train, y_train)
get_grid_best_params(grid)
# Out:
# Wall time: 0 ns
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# {'alpha': 0.25}
# BernoulliNB(alpha=0.25)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# C:\Users\user\anaconda3\anac\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\user\anaconda3\anac\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\user\anaconda3\anac\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# ...

# %%
print_grid_performance(grid, x_test, y_test)
# Out:
# Accuracy:  0.79
#
# Macro precision_recall_fscore_support (macro) average
# (0.7924679487179487, 0.794949494949495, 0.7898108297467721, None)
#
# Macro precision_recall_fscore_support (micro) average
# (0.79, 0.79, 0.79, None)
#
# Macro precision_recall_fscore_support (weighted) average
# (0.7986378205128204, 0.79, 0.7904413972575317, None)
#
# Confusion Matrix
# [[38  7]
#  [14 41]]

# %%
from xgboost import XGBClassifier

# %time
grid_params = {'learning_rate': [0.01, 0.05, 0.1], 
              'eval_metric': ['error']}

grid = get_trained_grid(XGBClassifier(), grid_params, x_train, y_train)
get_grid_best_params(grid)
# Out:
# Wall time: 0 ns
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# C:\Users\user\anaconda3\anac\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# C:\Users\user\anaconda3\anac\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# [Parallel(n_jobs=1)]: Done  30 out of  30 | elapsed:    7.5s finished
# ...

# %%
print_grid_performance(grid, x_test, y_test)
# Out:
# Accuracy:  0.91
#
# Macro precision_recall_fscore_support (macro) average
# (0.9086538461538461, 0.9121212121212121, 0.9095568284594513, None)
#
# Macro precision_recall_fscore_support (micro) average
# (0.91, 0.91, 0.91, None)
#
# Macro precision_recall_fscore_support (weighted) average
# (0.9120192307692306, 0.91, 0.9101899306602351, None)
#
# Confusion Matrix
# [[42  3]
#  [ 6 49]]

# %%
from sklearn.ensemble import RandomForestClassifier

# %time
clr = RandomForestClassifier(bootstrap=False, criterion="gini", max_features="log2", n_estimators=50)
clr.fit(x_train, y_train)
# Out:
# Wall time: 0 ns
# <ipython-input-37-643893fb2278>:5: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clr.fit(x_train, y_train)
# RandomForestClassifier(bootstrap=False, max_features='log2', n_estimators=50)

# %%
print_grid_performance(clr, x_train, y_train)
# Out:
# Accuracy:  1.0
#
# Macro precision_recall_fscore_support (macro) average
# (1.0, 1.0, 1.0, None)
#
# Macro precision_recall_fscore_support (micro) average
# (1.0, 1.0, 1.0, None)
#
# Macro precision_recall_fscore_support (weighted) average
# (1.0, 1.0, 1.0, None)
#
# Confusion Matrix
# [[445   0]
#  [  0 455]]

# %%
print_grid_performance(clr, x_test, y_test)
# Out:
# Accuracy:  0.88
#
# Macro precision_recall_fscore_support (macro) average
# (0.8811524609843937, 0.8848484848484848, 0.8798076923076923, None)
#
# Macro precision_recall_fscore_support (micro) average
# (0.88, 0.88, 0.88, None)
#
# Macro precision_recall_fscore_support (weighted) average
# (0.8869147659063625, 0.88, 0.8802884615384614, None)
#
# Confusion Matrix
# [[42  3]
#  [ 9 46]]

# %%
x_test = test.values
x_test = scaler.transform(x_test)
x_test[:5]
# Out:
# array([[ 2.76183168, -0.21497368, -0.53374498,  0.26537075,  0.14491296,
#         -0.02448615, -0.85912152,  1.62067541, -0.69357918, -0.86934711,
#         -0.22572048,  1.588274  ,  1.18112631,  1.16577415,  0.85653997,
#          0.07153014, -0.5179659 ,  0.14966661, -0.05771071, -0.1145711 ,
#         -1.18030155,  0.27963542, -1.39005426, -0.88029708, -0.34974493,
#          2.4625044 , -0.9040724 ,  0.78928503,  0.49403245, -0.57037122,
#         -0.28911902, -0.24711044, -0.50612166, -0.45792684,  0.11278037,
#         -0.70114006, -0.02215089,  0.00382642,  0.23426124,  1.08047326],
#        [-0.39661202,  0.55345601,  0.10744837,  0.78244762, -0.03903794,
#          2.59300396,  1.51379087,  0.76719428, -0.79006853, -1.20871362,
#         -0.36643325,  0.44085426, -0.97630359,  0.88469465, -0.1145605 ,
#         -2.23327486,  0.02498483,  0.27768491, -1.63584222,  0.61060689,
#          0.54051781, -0.18239726, -1.21097615, -1.33189453,  0.74446303,
# ...

# %%
submit = pd.DataFrame(clr.predict(x_test))
submission = pd.DataFrame(submit)
submission.columns = ['Solution']
submission['Id'] = np.arange(1,submission.shape[0]+1)
submission = submission[['Id','Solution']]

# %%
submission
# Out:
#         Id  Solution
# 0        1         1
# 1        2         0
# 2        3         0
# 3        4         0
# 4        5         0
# ...    ...       ...
# 8995  8996         1
# 8996  8997         1
# 8997  8998         1
# 8998  8999         0
# 8999  9000         1
#
# [9000 rows x 2 columns]

# %%
submission.to_csv('submission5.csv', index=False)
print(submission.shape)
# Out:
# (9000, 2)
